# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 0 5 ORG
# U.K. 27 31 GPE
# $1 billion 44 54 MONEY

# %%
doc2 = nlp("Bill Gates ht eine große Villa")

# %%
for ent in doc2.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Bill Gates 0 10 PERSON
# Villa 25 30 ORG

# %%
from nltk.corpus import gutenberg
import nltk
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /Users/sanaz/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
doc2[0].pos_
# Out:
# 'PROPN'

# %%
#Eigennamen (einzelne Namen werden aufgelistet, sowie Mr und Mrs als Propertyname )
personlist1 = []
for span in result:
    if span.pos_ == "PROPN":
        print(span.text)

# %%
#Vor und Nachname einer person(wenn vorhanden) wird aufgelistet, sowie Verben in Verbindungen mit Pronomen
from nltk.corpus import stopwords
filtered_tokens 
pronoun = ["he", "she", "was:--he", "himself", "herself"]
personlist = []
for span in result.ents:
    if span.label_ == "PERSON" and span.text not in pronoun:
        personlist.append(span)
        print(span.text, span.start, span.end, span.label_)
# Out:
# Henry Dashwood 158 160 PERSON
# Gentleman 199 200 PERSON
# Henry Dashwood 223 225 PERSON
# Henry Dashwood 279 281 PERSON
# Dashwood 521 522 PERSON
# Dashwood 762 763 PERSON
# Dashwood 889 890 PERSON
# John Dashwood 919 921 PERSON
# John Dashwood 981 983 PERSON
# John Dashwood 1108 1110 PERSON
# himself;-- 1115 1116 PERSON
# John
# Dashwood 1294 1297 PERSON
# Dashwood 1368 1369 PERSON
# John Dashwood 1429 1431 PERSON
# Dashwood 1485 1486 PERSON
# Elinor 1578 1579 PERSON
# Dashwood 1642 1643 PERSON
# Marianne 1706 1707 PERSON
# Elinor 1719 1720 PERSON
# Elinor 1776 1777 PERSON
# Dashwood 1794 1795 PERSON
# Elinor 1879 1880 PERSON
# Margaret 1949 1950 PERSON
# Marianne 1978 1979 PERSON
# John Dashwood 2017 2019 PERSON
# Dashwood 2117 2118 PERSON
# John Dashwood 2228 2230 PERSON
# Harry 2392 2393 PERSON
# Harry 2744 2745 PERSON
# Dashwood 3236 3237 PERSON
# Dashwood 3550 3551 PERSON
# Dashwood 3982 3983 PERSON
# Dashwood 4198 4199 PERSON
# John Dashwood 4304 4306 PERSON
# ...

# %%
print(personlist)

# %%
result[1079].pos_
# Out:
# 'VERB'

# %%
doc = gutenberg.raw('austen-sense.txt')
result = nlp(doc)

# %%
list = []
for ent in result.ents:
    if ent.label_ == "PERSON":
        if tag == 'NNP':
            list.append((ent.text, ent.label_))
            print(ent.text, ent.start_char, ent.end_char, ent.label_)
    
setperson = set(list)
# Out:
# Henry Dashwood 718 732 PERSON
# Gentleman 897 906 PERSON
# Henry Dashwood 1016 1030 PERSON
# Henry Dashwood 1281 1295 PERSON
# Dashwood 2339 2347 PERSON
# Dashwood 3337 3345 PERSON
# Dashwood 3912 3920 PERSON
# John Dashwood 4049 4062 PERSON
# John Dashwood 4323 4336 PERSON
# was:--he 4757 4765 PERSON
# John Dashwood 4884 4897 PERSON
# himself;-- 4925 4935 PERSON
# John
# Dashwood 5718 5731 PERSON
# Dashwood 6035 6043 PERSON
# John Dashwood 6310 6323 PERSON
# Dashwood 6570 6578 PERSON
# Elinor 6989 6995 PERSON
# Dashwood 7297 7305 PERSON
# Marianne 7595 7603 PERSON
# Elinor 7655 7661 PERSON
# Elinor 7908 7914 PERSON
# Dashwood 7986 7994 PERSON
# Elinor 8400 8406 PERSON
# Margaret 8713 8721 PERSON
# Marianne 8827 8835 PERSON
# John Dashwood 8992 9005 PERSON
# Dashwood 9437 9445 PERSON
# John Dashwood 9978 9991 PERSON
# Harry 10706 10711 PERSON
# Harry 12088 12093 PERSON
# Dashwood 14061 14069 PERSON
# Dashwood 15370 15378 PERSON
# Dashwood 17157 17165 PERSON
# ...

# %%
print(setperson)
# Out:
# {('Richard', 'PERSON'), ('Martha Sharpe', 'PERSON'), ('Pratt', 'PERSON'), ('Combe', 'PERSON'), ('him.--', 'PERSON'), ('Edward\nFerrars', 'PERSON'), ('Queen Mab', 'PERSON'), ('Dashwood;--but', 'PERSON'), ('Marianne', 'PERSON'), ('John Smith', 'PERSON'), ('Dashwoods', 'PERSON'), ('East Kingham Farm', 'PERSON'), ('Willoughby', 'PERSON'), ('before;--', 'PERSON'), ('Madam', 'PERSON'), ('Miss Morton', 'PERSON'), ('Brandon;--he', 'PERSON'), ('Taylor', 'PERSON'), ('love;--', 'PERSON'), ('Barton', 'PERSON'), ('John\n', 'PERSON'), ('Somersetshire', 'PERSON'), ('Ellison', 'PERSON'), ('Cruel', 'PERSON'), ('John.--"It', 'PERSON'), ('Abundance', 'PERSON'), ('Down', 'PERSON'), ('Shakespeare', 'PERSON'), ("Miss Grey's", 'PERSON'), ('Edward', 'PERSON'), ('Elliott', 'PERSON'), ('John Willoughby', 'PERSON'), ('Margaret', 'PERSON'), ('Lady Middleton', 'PERSON'), ('Elinor;--', 'PERSON'), ('Brandon', 'PERSON'), ('Dashwood', 'PERSON'), ('Magna', 'PERSON'), ('signify?--For', 'PERSON'), ('Sally', 'PERSON'), 
# ...

# %%
setperson
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 2
#       1 NER = spacy.load("en_core_web_sm")
# ----> 2 text = setperson.join()
#       4 for names in text:
#       5     print(ent.text, ent.label_)
#
# AttributeError: 'set' object has no attribute 'join'

# %%
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']
