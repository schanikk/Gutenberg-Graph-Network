# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 0 5 ORG
# U.K. 27 31 GPE
# $1 billion 44 54 MONEY

# %%
doc2 = nlp("Bill Gates ht eine große Villa")

# %%
for ent in doc2.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Bill Gates 0 10 PERSON
# Villa 25 30 ORG

# %%
from nltk.corpus import gutenberg
import nltk
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /Users/sanaz/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
doc2[0].pos_
# Out:
# 'PROPN'

# %%
doc = gutenberg.paras('austen-sense.txt')

# %%
doc = [' '.join(e) for para in doc for e in para]

# %%
doc
# Out:
# ['[ Sense and Sensibility by Jane Austen 1811 ]',
#  'CHAPTER 1',
#  'The family of Dashwood had long been settled in Sussex .',
#  'Their estate was large , and their residence was at Norland Park , in the centre of their property , where , for many generations , they had lived in so respectable a manner as to engage the general good opinion of their surrounding acquaintance .',
#  'The late owner of this estate was a single man , who lived to a very advanced age , and who for many years of his life , had a constant companion and housekeeper in his sister .',
#  'But her death , which happened ten years before his own , produced a great alteration in his home ; for to supply her loss , he invited and received into his house the family of his nephew Mr . Henry Dashwood , the legal inheritor of the Norland estate , and the person to whom he intended to bequeath it .',
# ...

# %%
def create_entities(docs):
    pronoun = ["he", "she", "was:--he", "himself", "herself", "himself;--"]
    personlist = []
    for key,value in docs.items():
        print(f"Para {key} ")
        for span in value.ents:
            if span.label_ == "PERSON" and span.text not in pronoun:
                personlist.append(span)
                print(span.text, span.start, span.end, span.label_)
    return personlist

# %%
def load_and_process():
    fileids_ = gutenberg.fileids()
    final_result = dict()
    for fileid in fileids_:
        doc = gutenberg.paras(fileid)
        doc = [' '.join(e) for para in doc for e in para]
        results_ = dict()
        for i, d in enumerate(doc):
            res = nlp(d)
            results_[i] = res
        final_result[fileid]=create_entities(results_)

    return final_result

# %%
load_and_process()
# Out:
# [ Emma by Jane Austen 1816 ]
# [ Persuasion by Jane Austen 1818 ]
# [ Sense and Sensibility by Jane Austen 1811 ]
# [ The King James Bible ]
# [ Poems by William Blake 1789 ]
# [ Stories to Tell to Children by Sara Cone Bryant 1918 ]
# [ The Adventures of Buster Bear by Thornton W . Burgess 1920 ]
# [ Alice ' s Adventures in Wonderland by Lewis Carroll 1865 ]
# [ The Ball and The Cross by G . K . Chesterton 1909 ]
# [ The Wisdom of Father Brown by G . K . Chesterton 1914 ]
# [ The Man Who Was Thursday by G . K . Chesterton 1908 ]
# [ The Parent ' s Assistant , by Maria Edgeworth ]
# [ Moby Dick by Herman Melville 1851 ]
# [ Paradise Lost by John Milton 1667 ]
# [ The Tragedie of Julius Caesar by William Shakespeare 1599 ]
# [ The Tragedie of Hamlet by William Shakespeare 1599 ]
# [ The Tragedie of Macbeth by William Shakespeare 1603 ]
# [ Leaves of Grass by Walt Whitman 1855 ]
# {}

# %%
#Vor und Nachname einer person(wenn vorhanden) wird aufgelistet

pronoun = ["he", "she", "was:--he", "himself", "herself", "himself;--"]
personlist = []
for key,value in results_.items():
    print(f"Para {key} ")
    for span in value.ents:
        if span.label_ == "PERSON" and span.text not in pronoun:
            personlist.append(span)
            print(span.text, span.start, span.end, span.label_)
# Out:
# Para 0
# Para 1
# Para 2
# Para 3
# Para 4
# Para 5
# Henry Dashwood 40 42 PERSON
# Para 6
# Gentleman 15 16 PERSON
# Para 7
# Para 8
# Mrs 7 8 PERSON
# Henry Dashwood 9 11 PERSON
# Para 9
# Henry Dashwood 7 9 PERSON
# Para 10
# Para 11
# Para 12
# Para 13
# Para 14
# Para 15
# Para 16
# Para 17
# Para 18
# Para 19
# Para 20
# Para 21
# Para 22
# Para 23
# John Dashwood 2 4 PERSON
# Para 24
# John Dashwood 13 15 PERSON
# Para 25
# Para 26
# Para 27
# Mrs 1 2 PERSON
# John Dashwood 3 5 PERSON
# Para 28
# Para 29
# Para 30
# Para 31
# Para 32
# Para 33
# Para 34
# Para 35
# John Dashwood 13 15 PERSON
# Para 36
# Para 37
# John Dashwood 2 4 PERSON
# Para 38
# Mrs 3 4 PERSON
# Para 39
# Elinor 0 1 PERSON
# Para 40
# Para 41
# Marianne 0 1 PERSON
# Elinor 13 14 PERSON
# Para 42
# Para 43
# Para 44
# Para 45
# Elinor 0 1 PERSON
# Mrs 17 18 PERSON
# Para 46
# Para 47
# Para 48
# Para 49
# Elinor 0 1 PERSON
# Para 50
# Para 51
# Margaret 0 1 PERSON
# Marianne 27 28 PERSON
# Para 52
# ...

# %%
print(personlist)

# %%
result[1079].pos_
# Out:
# 'VERB'

# %%
documents = gutenberg.fileids()
print (documents)
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %%
pronoun = ["he", "she", "was:--he", "himself", "herself", "himself;--"]
personlist1 = []
for i,fileNames in documents:
    documents(i)
    for key,value in documents(i):
          print(f"Para {key} ")
          for span in value.ents:
            if span.label_ == "PERSON" and span.text not in pronoun:
              personlist1.append(span)
              print(span.text, span.start, span.end, span.label_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 3
#       1 pronoun = ["he", "she", "was:--he", "himself", "herself", "himself;--"]
#       2 personlist1 = []
# ----> 3 for i,fileNames in documents:
#       4     documents(i)
#       5     for key,value in documents(i):
#
# ValueError: too many values to unpack (expected 2)

# %%
def Document():
    for fileName in documents:
        input = Document()
        print(input)
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']
